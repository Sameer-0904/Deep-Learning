# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\HP\\OneDrive\\Desktop\\Deep Learning\\Deep-Learning\\data\\DailyDelhiClimateTest.csv")

# %%
df.head()
# Out:
#          date   meantemp  wind_speed  meanpressure   humidity
# 0  01-01-2017  15.913043    2.743478     59.000000  85.869565
# 1  02-01-2017  18.500000    2.894444   1018.277778  77.222222
# 2  03-01-2017  17.111111    4.016667   1018.333333  81.888889
# 3  04-01-2017  18.700000    4.545000   1015.700000  70.050000
# 4  05-01-2017  18.388889    3.300000   1014.333333  74.944444

# %%
df.drop(columns=['wind_speed','meanpressure','humidity'], inplace=True)

# %%
df.head()
# Out:
#          date   meantemp
# 0  01-01-2017  15.913043
# 1  02-01-2017  18.500000
# 2  03-01-2017  17.111111
# 3  04-01-2017  18.700000
# 4  05-01-2017  18.388889

# %%
plt.scatter(df['date'], df['meantemp'], color='red')

# %%
x1 = df['meantemp'].ewm(alpha=0.1).mean()

# %%
x1
# Out:
# 0      15.913043
# 1      17.274600
# 2      17.214272
# 3      17.646295
# 4      17.827632
#          ...
# 109    30.640166
# 110    31.001152
# 111    31.191039
# 112    31.359436
# 113    31.423493
# Name: meantemp, Length: 114, dtype: float64

# %%
df['ewm'] = x1
df.head()
# Out:
#          date   meantemp        ewm
# 0  01-01-2017  15.913043  15.913043
# 1  02-01-2017  18.500000  17.274600
# 2  03-01-2017  17.111111  17.214272
# 3  04-01-2017  18.700000  17.646295
# 4  05-01-2017  18.388889  17.827632

# %%
plt.scatter(df['date'], df['meantemp'], color='red')
plt.plot(df['date'], x1, color='black', label='alpha=0.9')
plt.legend()
plt.show()
